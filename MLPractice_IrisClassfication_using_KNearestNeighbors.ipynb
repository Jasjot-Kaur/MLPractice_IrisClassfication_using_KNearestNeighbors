# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasjot-Kaur/MLPractice_IrisClassfication_using_KNearestNeighbors/blob/main/MLPractice_IrisClassfication_using_KNearestNeighbors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # K Nearest Neighbors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns = iris.feature_names)
df['Class'] = iris.target
df['Class name'] = iris.target_names[iris['target']]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Class Class name
# 0      0     setosa
# 1      0     setosa
# 2      0     setosa
# 3      0     setosa
# 4      0     setosa

# %%
sns.pairplot(df)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size = 0.2, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 10)           # default neighbors = 5
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
model.predict([[5.6, 4.4, 1.2, 0.4]])
# Out:
# array([0])

# %%
model.predict([[2,4,6,8]])
# Out:
# array([2])
